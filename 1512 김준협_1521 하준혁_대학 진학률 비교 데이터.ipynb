# %%
import csv
f = open ('대학 진학률.csv')
data = csv.reader(f)

한과영 = []
서울과고 = []
대구과고 = []
경기과고 = []
한성과고 = []
세종과고 = []
경기북과고 = []

서울대1 = []
KAIST1 = []
포스텍1 = []
GIST1 = []
DGIST1 = []

서울대2 = []
KAIST2 = []
포스텍2 = []
GIST2 = []
DGIST2 = []

서울대3 = []
KAIST3 = []
포스텍3 = []
GIST3 = []
DGIST3 = []

서울대4 = []
KAIST4 = []
포스텍4 = []
GIST4 = []
DGIST4 = []

서울대5 = []
KAIST5 = []
포스텍5 = []
GIST5 = []
DGIST5 = []

서울대6 = []
KAIST6 = []
포스텍6 = []
GIST6 = []
DGIST6 = []

서울대7 = []
KAIST7 = []
포스텍7 = []
GIST7 = []
DGIST7 = []

for row in data:
    if row[0] == '한과영':
        for i in range(1,6) :
            한과영.append(int(row[i]))
서울대1 = 한과영[::5]
KAIST1 = 한과영[1::5]
포스텍1 = 한과영[2::5]
GIST1 = 한과영[3::5]
DGIST1 = 한과영[4::5]

for row in data:
    if row[0] == '대구과고':
        for i in range(1,6) :
            대구과고.append(int(row[i]))
서울대2 = 대구과고[::5]
KAIST2 = 대구과고[1::5]
포스텍2 = 대구과고[2::5]
GIST2 = 대구과고[3::5]
DGIST2 = 대구과고[4::5]

for row in data:
    if row[0] == '경기과고':
        for i in range(1,6) :
            경기과고.append(int(row[i]))
서울대3 = 경기과고[::5]
KAIST3 = 경기과고[1::5]
포스텍3 = 경기과고[2::5]
GIST3 = 경기과고[3::5]
DGIST3 = 경기과고[4::5]

for row in data:
    if row[0] == '서울과고':
        for i in range(1,6) :
            서울과고.append(int(row[i]))
서울대4 = 서울과고[::5]
KAIST4 = 서울과고[1::5]
포스텍4 = 서울과고[2::5]
GIST4 = 서울과고[3::5]
DGIST4 = 서울과고[4::5]

for row in data:
    if row[0] == '한성과고':
        for i in range(1,6) :
            한성과고.append(int(row[i]))
서울대5 = 한성과고[::5]
KAIST5 = 한성과고[1::5]
포스텍5 = 한성과고[2::5]
GIST5 = 한성과고[3::5]
DGIST5 = 한성과고[4::5]

for row in data:
    if row[0] == '세종과고':
        for i in range(1,6) :
            세종과고.append(int(row[i]))
서울대6 = 세종과고[::5]
KAIST6 = 세종과고[1::5]
포스텍6 = 세종과고[2::5]
GIST6 = 세종과고[3::5]
DGIST6 = 세종과고[4::5]

for row in data:
    if row[0] == '경기북과고':
        for i in range(1,6) :
            경기북과고.append(int(row[i]))
서울대7 = 경기북과고[::5]
KAIST7 = 경기북과고[1::5]
포스텍7 = 경기북과고[2::5]
GIST7 = 경기북과고[3::5]
DGIST7 = 경기북과고[4::5]

import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')
plt.plot(서울대1,'b^', lw=3, label = '서울대1')
plt.plot(KAIST1,'g^', lw=3, label = 'KAIST1')
plt.plot(포스텍1,'c^', lw=3, label = '포스텍1')
plt.plot(GIST1,'y^', lw=3, label = 'GIST1')
plt.plot(DGIST1,'r^', lw=3, label = 'DGIST1')

plt.plot(서울대2,'b*', lw=3, label = '서울대2')
plt.plot(KAIST2,'g*', lw=3, label = 'KAIST2')
plt.plot(포스텍2,'c*', lw=3, label = '포스텍2')
plt.plot(GIST2,'y*', lw=3, label = 'GIST2')
plt.plot(DGIST2,'r*', lw=3, label = 'DGIST2')

plt.plot(서울대3,'b--', lw=3, label = '서울대3')
plt.plot(KAIST3,'g--', lw=3, label = 'KAIST3')
plt.plot(포스텍3,'c--', lw=3, label = '포스텍3')
plt.plot(GIST3,'y--', lw=3, label = 'GIST3')
plt.plot(DGIST3,'r--', lw=3, label = 'DGIST3')

plt.plot(서울대4,'bo', lw=3, label = '서울대4')
plt.plot(KAIST4,'go', lw=3, label = 'KAIST4')
plt.plot(포스텍4,'co', lw=3, label = '포스텍4')
plt.plot(GIST4,'yo', lw=3, label = 'GIST4')
plt.plot(DGIST4,'ro', lw=3, label = 'DGIST4')

plt.plot(서울대5,'b-', lw=3, label = '서울대5')
plt.plot(KAIST5,'g-', lw=3, label = 'KAIST5')
plt.plot(포스텍5,'c-', lw=3, label = '포스텍5')
plt.plot(GIST5,'y-', lw=3, label = 'GIST5')
plt.plot(DGIST5,'r-', lw=3, label = 'DGIST5')

plt.plot(서울대6,'b+', lw=3, label = '서울대6')
plt.plot(KAIST6,'g+', lw=3, label = 'KAIST6')
plt.plot(포스텍6,'c+', lw=3, label = '포스텍6')
plt.plot(GIST6,'y+', lw=3, label = 'GIST6')
plt.plot(DGIST6,'r+', lw=3, label = 'DGIST6')

plt.plot(서울대7,'bs', lw=10, label = '서울대7')
plt.plot(KAIST7,'gs', lw=10, label = 'KAIST7')
plt.plot(포스텍7,'cs', lw=10, label = '포스텍7')
plt.plot(GIST7,'ys', lw=100, label = 'GIST7')
plt.plot(DGIST7,'rs', lw=10, label = 'DGIST7')

plt.legend()
plt.xticks(np.arange(0, 4, 1))
plt.rcParams["figure.figsize"] = (50,50)
plt.show()

print(서울대1)
print(KAIST1)
print(포스텍1)
print(GIST1)
print(DGIST1)
f.close()
# Out:
# [19, 33, 25, 33]
# [80, 91, 94, 95]
# [5, 2, 3, 3]
# [1, 1, 0, 0]
# [5, 3, 2, 1]

# %%
for row in data:
    if row[0] == '대구과고':
        for i in range(1,6) :
            대구과고.append(int(row[i]))
서울대2 = 대구과고[::5]
KAIST2 = 대구과고[1::5]
포스텍2 = 대구과고[2::5]
GIST2 = 대구과고[3::5]
DGIST2 = 대구과고[4::5]

for row in data:
    if row[0] == '경기과고':
        for i in range(1,6) :
            경기과고.append(int(row[i]))
서울대3 = 경기과고[::5]
KAIST3 = 경기과고[1::5]
포스텍3 = 경기과고[2::5]
GIST3 = 경기과고[3::5]
DGIST3 = 경기과고[4::5]

for row in data:
    if row[0] == '서울과고':
        for i in range(1,6) :
            서울과고.append(int(row[i]))
서울대4 = 서울과고[::5]
KAIST4 = 서울과고[1::5]
포스텍4 = 서울과고[2::5]
GIST4 = 서울과고[3::5]
DGIST4 = 서울과고[4::5]

for row in data:
    if row[0] == '한성과고':
        for i in range(1,6) :
            한성과고.append(int(row[i]))
서울대5 = 한성과고[::5]
KAIST5 = 한성과고[1::5]
포스텍5 = 한성과고[2::5]
GIST5 = 한성과고[3::5]
DGIST5 = 한성과고[4::5]

for row in data:
    if row[0] == '세종과고':
        for i in range(1,6) :
            세종과고.append(int(row[i]))
서울대6 = 세종과고[::5]
KAIST6 = 세종과고[1::5]
포스텍6 = 세종과고[2::5]
GIST6 = 세종과고[3::5]
DGIST6 = 세종과고[4::5]

for row in data:
    if row[0] == '경기북과고':
        for i in range(1,6) :
            경기북과고.append(int(row[i]))
서울대7 = 경기북과고[::5]
KAIST7 = 경기북과고[1::5]
포스텍7 = 경기북과고[2::5]
GIST7 = 경기북과고[3::5]
DGIST7 = 경기북과고[4::5]
